# %% [markdown]
# # Synthetic Traces for the tool.

# %%
import json
import langchain
from langchain.llms import FakelistLLM

traces = []

with open("src/data/traces.json", "w") as f:
    json.dump(traces,f)
